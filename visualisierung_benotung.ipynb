# %% [markdown]
# # Visualisierung Klassenbenotung
# ## To-do
# * Visualisierung Schularbeiten
# * Visualisierung Wiederholungen
# * Visualisierung Gesamtnote

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel('./Excel-Vorlagen/Vorlage_Benotung_TAG.xlsx')

# %%
data.head(3)
# Out:
#   Unnamed: 0 1EK - Notenstand  Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0        NaN              NaN         NaN        NaN         m/w
# 1     Klasse              Nr.    Nachname    Vorname  Geschlecht
# 2        HAK                1  Nachname 1  Vorname 1           w
#
#        Unnamed: 5      Unnamed: 6  Unnamed: 7     Unnamed: 8 Unnamed: 9  ...  \
# 0             NaN             NaN         NaN  REPASOS (20%)        NaN  ...
# 1  Wintersemester  Sommersemester         NaN         Punkte      Summe  ...
# 2         2023/24            2024    0.590369           49.5         86  ...
#
#    Unnamed: 41              Unnamed: 42                Unnamed: 43  \
# 0          NaN                      NaN                        NaN
# 1  Frühwarnung  Notenstand (09.05.2024)                  Mitarbeit
# 2           JA           Nicht genügend  aktiver im Sommersemester
#
#                                          Unnamed: 44     Unnamed: 45  \
# ...

# %%
# Set the appropriate row as the header and drop the rows above
data.columns = data.iloc[1]  # Row 3 becomes the header (index 2)
data = data.drop([0,1])  # Drop rows above the new header

# Reset the index
data = data.reset_index(drop=True)

# Display the cleaned DataFrame
data
# Out:
# 1 Klasse Nr.    Nachname    Vorname Geschlecht Wintersemester Sommersemester  \
# 0    HAK   1  Nachname 1  Vorname 1          w        2023/24           2024
# 1    HAK   2  Nachname 2  Vorname 2          m        2023/24           2024
# 2    HAK   3  Nachname 3  Vorname 3          w        2023/24           2024
# 3    HAK   4  Nachname 4  Vorname 4          w        2023/24           2024
# 4    HAK   5  Nachname 5  Vorname 5          w        2023/24           2024
# 5    HAK   6  Nachname 6  Vorname 6          w        2023/24           2024
# 6    HAK   7  Nachname 7  Vorname 7          w        2023/24           2024
#
# 1       NaN Punkte Summe  ... Frühwarnung  Notenstand (09.05.2024)  \
# 0  0.590369   49.5    86  ...          JA           Nicht genügend
# 1  0.883463   76.5    86  ...         NaN           Sehr gut - Gut
# 2  0.655926     50    86  ...         NaN  Befriedigend - Genügend
# 3  0.664408  47.75    74  ...         NaN                 Genügend
# ...

# %%
data.columns
# Out:
# Index([                         'Klasse',                             'Nr.',
#                               'Nachname',                         'Vorname',
#                             'Geschlecht',                  'Wintersemester',
#                         'Sommersemester',                               nan,
#                                 'Punkte',                           'Summe',
#                                'Prozent',                       'FUNKTION!',
#                                 'Punkte',                           'Summe',
#                                'Prozent',                      'Zusatzinfo',
#                                   'Note',                               nan,
#                              'abgegeben',                       'verspätet',
#                          'fehlt, falsch',                           'SUMME',
#                                      nan,                               nan,
# ...

# %% [markdown]
# ### Notwendige Änderungen:
# * alle Spalten passend benennen
